# %% [markdown]
# # Nivel 1-2: Muy básicos (entender y contar lo obvio)

# %% [markdown]
# ## Ejercicio 1: Notas de un Examen
#
#
# **Datos:** Lista de notas (0-10) de una clase.
#
# notas = [7, 8, 6, 9, 7, 5, 8, 7, 6, 4, 9, 8, 7, 10, 6, 7, 8, 5, 9, 7]
#
# **Tareas:**
# 1. Calcular media, mediana y moda
# 2. Responder por escrito:
#    - ¿La nota "típica" del grupo es más cercana a la media o a la mediana?
#    - ¿Qué medida usarías para explicar el rendimiento general al claustro? ¿Por qué?

# %% [markdown]
# ## Ejercicio 2: Horas de Estudio Semanales
#
# Se realizó una encuesta a un grupo de estudiantes sobre la cantidad de horas que dedican a estudiar por semana. Los datos obtenidos son:
#
# **Datos**: 5, 8, 6, 7, 50, 6, 8, 7, 5, 6
#
# ## Tareas:
# 1. Calcular la **media** y la **mediana**
# 2. **Comparar** ambas medidas
# 3. **Explicar** qué dice eso sobre el hábito de estudio del grupo
#
# 💡 **Pista didáctica**: Observe cómo los valores extremos pueden "engañar" a la media

# %% [markdown]
# # Nivel 3–4 · Introducir dispersión y variabilidad

# %% [markdown]
# ## Ejercicio 3: Sueldos en una empresa pequeña
#
# En una empresa pequeña se registraron los sueldos mensuales de sus empleados. Uno de ellos (el gerente) tiene un sueldo muy alto comparado con el resto.
#
# **Datos (ejemplo)**: 1200, 1400, 1350, 1500, 1600, 1450, 1300, 1250, 1800, 10000
#
# ## Tareas
# - Calcular **media**, **mediana** y **desviación estándar**.
# - Explicar:
#   - ¿La media representa bien al "empleado medio"?
#   - ¿Qué nos dice la desviación estándar sobre la **desigualdad salarial**?
#
# 💡 Pista didáctica: el sueldo del gerente es un **valor extremo** que puede **sesgar la media**.

# %% [markdown]
# ## Ejercicio 4: Tiempo para llegar al trabajo
# Se registraron los **minutos de desplazamiento** diario al trabajo para un grupo de empleados.
#
# **Datos (ejemplo)**: 15, 20, 18, 22, 19, 17, 45, 60, 16, 21
#
# ## Tareas
# - Calcular **media**, **mediana** y **desviación estándar**.
# - Interpretar:
#   - ¿El grupo es **homogéneo** o hay **grandes diferencias**?
#   - ¿Qué tipo de trabajador tiene **peor experiencia diaria**?
#
# 💡 Pista didáctica: algunos trayectos largos (valores extremos) pueden **inflar la media** y aumentar la **desviación estándar**.

# %% [markdown]
# #  Nivel 5–6 · Outliers y análisis crítico

# %% [markdown]
# ##  Ejercicio 5
#
# Se registraron las **ventas diarias** de una tienda a lo largo de un **mes**. Hubo **un día con ventas muy altas** respecto al resto.
#
# ## Tareas
# - Detectar **posibles outliers**.
# - Calcular **media** y **mediana** **con y sin** ese valor.
# - Explicar **qué pudo pasar** ese día (rebajas, campaña, error…).
#
# 🎯 Storytelling: "**Un solo día excepcional** distorsiona la **percepción** del mes completo".

# %% [markdown]
# ## Ejercicio 6: Uso del móvil al día
#
# Se registraron las **horas diarias de uso del móvil** de un grupo de personas durante un periodo reciente.
#
# ## Tareas
# - Calcular **media**, **mediana** y **desviación estándar**.
# - **Identificar outliers** (usos extremadamente altos o bajos).
# - Explicar si existe un **uso normal** o varios **perfiles de usuarios**.
#
# 🎯 Pista didáctica: valores muy altos de uso pueden sesgar la media y aumentar la variabilidad percibida.

# %% [markdown]
# # Nivel 7–8 · Diagramas de caja (bigotes)

# %% [markdown]
# ## Ejercicio 7: Notas por trimestre
#
#
# Se tienen las **notas del mismo grupo** en **3 trimestres**.
#
# trimestre1 = [5.5, 6.0, 5.8, 6.2, 7.0, 6.5, 5.9, 6.1, 7.2, 6.8, 5.4, 6.0, 6.3]
#
# trimestre2 = [6.2, 6.5, 6.8, 7.1, 7.3, 6.9, 7.0, 6.7, 7.5, 7.4, 6.6, 7.2, 7.1]
#
# trimestre3 = [7.0, 7.2, 7.5, 7.8, 8.0, 7.9, 7.6, 7.7, 8.2, 8.1, 7.4, 7.3, 7.9]
#
# ## Tareas
# - Crear un **diagrama de caja** por trimestre.
# - Comparar **mediana** y **rango intercuartílico (IQR)** de cada trimestre.
# - Explicar la **evolución del grupo**.
#
# 🎯 Storytelling: "No solo sube la **nota central**, también se **reduce la dispersión**…"

# %% [markdown]
# ## Ejercicio 8: Consumo de datos móviles
#
# Se registró el **consumo de datos (GB)** de distintos usuarios durante un periodo reciente.
#
# ## Consumo de datos (GB) por usuario; incluye algunos consumidores intensivos
# consumo_gb = [4.2, 3.8, 5.1, 2.9, 3.5, 4.0, 6.2, 5.5, 3.1, 2.7,
#               12.0, 15.5, 4.3, 3.9, 5.0, 6.8, 7.2, 2.5, 3.0, 4.8]
#
# ## Tareas
# - Crear un **boxplot** del consumo.
# - Identificar **outliers**.
# - Clasificar **perfiles**: bajo, medio, intensivo.
#
# 💡 Aquí se ve muy bien el valor visual del **bigote** para detectar extremos sin usar gráficos complejos.

# %% [markdown]
# # Nivel 9–10 · Storytelling completo (tipo mini-informe)

# %% [markdown]
# ## Ejercicio 9: Comparación entre dos grupos (mañana vs tarde)
#
# Se registraron las **horas diarias de estudio** de dos grupos del mismo curso:
# - **Grupo A (mañana)**
# - **Grupo B (tarde)**
#
# ## Datos sintéticos: medias similares, variabilidad distinta y algunos extremos en B
# A = [6.5, 7.0, 6.8, 7.2, 6.9, 7.1, 6.7, 7.0, 6.6, 6.9, 7.3, 6.8, 7.0, 6.7, 7.1]
#
# B = [6.4, 7.1, 3.0, 9.5, 6.8, 7.0, 2.5, 8.8, 6.9, 7.2, 10.0, 5.5, 6.6, 7.4, 4.2]
#
# ## Tareas
# - Calcular **todas las medidas** descriptivas principales.
# - Crear **diagramas de caja** comparativos.
# - Escribir una **conclusión**: ¿qué grupo es más **constante**? ¿cuál tiene más **casos extremos**?
#
# 🎯 Storytelling: "Aunque ambos grupos estudian una **media similar**, su **comportamiento** es muy distinto…"

# %% [markdown]
# ## Ejercicio 10. Mini proyecto de análisis
#
# Contexto: dataset libre (notas, salarios, consumo, tiempos, etc.).
#
# ## Tareas
#
# Cálculo de todas las medidas vistas.
#
# Detección de outliers.
#
# Al menos un diagrama de caja.
#
# Informe final (10–15 líneas) respondiendo:
#
# ¿Qué está pasando en estos datos?
#
# ¿Qué conclusiones sacarías para tomar una decisión?

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Dataset ejemplo

# %%
# Datos de ejemplo: horas de estudio semanales
datos = {
    "alumno": [
        "Ane", "Iker", "Jon", "Maialen", "Unai",
        "Nerea", "Aitor", "Leire", "Mikel", "Irati",
        "Asier", "June", "Oier", "Uxue", "Markel"
    ],
    "horas_estudio": [
        5, 6, 7, 6, 8,
        5, 6, 7, 6, 40,  # posible outlier
        5, 6, 7, 6, 8
    ]
}

df = pd.DataFrame(datos)
df
# Out:
#      alumno  horas_estudio
# 0       Ane              5
# 1      Iker              6
# 2       Jon              7
# 3   Maialen              6
# 4      Unai              8
# 5     Nerea              5
# 6     Aitor              6
# 7     Leire              7
# 8     Mikel              6
# 9     Irati             40
# 10    Asier              5
# 11     June              6
# 12     Oier              7
# 13     Uxue              6
# 14   Markel              8

# %% [markdown]
# ### Medidas de tendencia central

# %% [markdown]
# ## TODO
# - ¿Cuál representa mejor al alumno “típico”?
# - ¿Por qué la media es mayor/menor que la mediana?

# %% [markdown]
# ### Medidas de dispersión

# %% [markdown]
# ## TODO
# - ¿El grupo es homogéneo o muy diverso?
# - ¿Qué indica la desviación estándar?

# %% [markdown]
# ### Detección de outliers (método IQR)

# %% [markdown]
# ### TODO
# - ¿Cuántos outliers hay?
# - ¿Qué explicación real podría haber detrás?

# %% [markdown]
# ### Comparación con y sin outliers

# %% [markdown]
# ### TODO
# - ¿Cómo cambia la percepción del grupo?
# - ¿Qué medida usarías para informar al profesorado?

# %% [markdown]
# ### Diagrama de caja

# %% [markdown]
# ### TODO
# - Describe el gráfico sin usar números
# - ¿Dónde se concentra la mayoría?

# %% [markdown]
# ### STORYTELLING
#
# Conclusión:
#
# La mayoría del alumnado dedica alrededor de _____ horas semanales al estudio,
# como indica la ____mediana________.
#
# La media es ____ horas_____ debido a _______________________.
#
# La dispersión de los datos es ______________________,
# lo que indica que el grupo es ______________________.
#
# Se detectan valores atípicos que representan ____________________,
# los cuales ______________________ la interpretación general.
